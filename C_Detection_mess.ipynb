# %%
from env import SCIENTIST

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time

# %%
import importlib # for reloading .py files
# WARNING: updates of config may require restart of kernel if reload is unsuccessful

import config
# reload config without restarting the kernel
importlib.reload(config)
from config import actions, no_sequences, sequence_length, number_of_classes, DATA_PATH, WEIGHTS_PATH, facemesh_included, is_martin

import utils
# reload utils without restarting the kernel
importlib.reload(utils)
from utils import mediapipe_detection, extract_keypoints, draw_styled_landmarks, prob_viz


import model
# reload model without restarting the kernel
importlib.reload(model)
from model import create_model, build_which_model

# %% [markdown]
# # CHOOSE MODEL / WEIGHTS

# %%
# name of the weights file (without ".keras" ending) 
# also used as model name - dot not allowed, thus deleted, and file renamed
model_name = "model_bowmore"
weights_name = model_name

# %% [markdown]
# # BUILD THE MODEL - CHRIS

# %%
# OPTIONAL model() arguments
# available model_types: "LSTM", "Conv2D"
# tested activation functions: "tanh", "relu"; OTHERS: see below 
# tested activations for last neural layer: "softmax", "sigmoid"; OTHERS: "linear", "tanh", "relu", "softplus", "softsign", "selu", "elu", "exponential"
# neural multiplicator: multiply neurons per layer by this amount (default = 1); the higher NM, the longer the computation
# output will change according if facemesh_included = True or False

# reLU = Rectified Linear Activation Function: returns 0 if it receives any negative input, but for any positive value x it returns that value back.  It helps the model to account for non-linearity.
# Sigmoid: Outputs a value between 0 and 1, making it suitable for binary classification or multilabel classification tasks where each label is predicted independently.
model_type, activation_function, activation, neural_multiplicator = "LSTM", "tanh", "softmax", 20
model = create_model(model_type, activation_function, activation, neural_multiplicator)
# Out:
# c:\Users\Veronika\Documents\20240117_WBS_Data_Science\Repos\RealTimeObjectDetection-1\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ['categorical_accuracy', 'accuracy', 'Precision', 'Recall']

# %% [markdown]
# # CALL THE MODEL - Martin

# %%
facemesh_included
# Out:
# False

# %%
if SCIENTIST == "Martin" or SCIENTIST == "Vero": 
    model = build_which_model(model_name)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 30, 128)        │       198,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 30, 256)        │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 17)             │           561 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 800,401 (3.05 MB)
#  Trainable params: 800,401 (3.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Loading weights

# %%
model.load_weights(os.path.join(WEIGHTS_PATH, weights_name + ".keras"))
# Out:
# c:\Users\Veronika\Documents\20240117_WBS_Data_Science\Repos\RealTimeObjectDetection-1\venv\lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 31 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# # PROBABILITY VIZUALIZATION - REAL TIME TESTING

# %%
import mediapipe as mp
from scipy.stats import mode

# %%
from utils import mp_holistic, mp_drawing, set_camera_settings, default_fps
import datetime

# %%
### FPS FIXIN

# %%
actions = ['background',
 'NoHands',
 'ILoveYou',
 'Yes',
 'No',
 'Hi',
 'ThankYou',
 'Me',
 'You',
 'It',
 'Feel',
 'Happy',
 'Hungry',
 'Eat',
 'Bread',
 'Chocolate',
 'Tired']

# %%
def prob_viz(res, actions, input_frame, threshold):
    fontScale = 1

    one_color = (245,117,16)
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        color = one_color if prob < threshold else (0,0,255)
        cv2.rectangle(output_frame, (0,60+num*30), (int(prob*100), 90+num*30), color, -1) #colors[num%len(colors)]
        cv2.putText(output_frame, str(int(prob * 100)) + "%" + " " + actions[num], 
                    (0, 85+num*30), cv2.FONT_HERSHEY_SIMPLEX, fontScale, (0,0,0), 4, cv2.LINE_AA)
        # Then draw the text again with the original color (e.g., white)
        cv2.putText(output_frame, str(int(prob * 100)) + "%" + " " + actions[num], 
                    (0, 85+num*30), cv2.FONT_HERSHEY_SIMPLEX, fontScale, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
import time
# 1. New detection variables
sequence = []
sentence = []
predictions = []
all_words = [] 
threshold = 0.4 # 40% 
fps_list = []
last_word = ""
num_of_words = 5

frame_counter = 0

frame_count_for_fps = 0
start_time = time.time()

length_of_sequence = 30
no_of_reps_to_accept = 5
silent_sign_name = "NoHands"

# picture of a static person using no hands as fall-back option for model
static_frame = np.load(os.path.join(DATA_PATH, "_.npy"))



cap = cv2.VideoCapture(0)  # Adjust device index as needed
actual_res, actual_fps = set_camera_settings(cap) # setting camera resolution and fps + printing the actual values
desired_fps = 7
frame_time = 1.0 / desired_fps
last_time = time.time()



#TODO: put recording in subfolder
# recording
timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
video_file_name = f"recording_{timestamp}.avi"
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(video_file_name, fourcc, 10.0, (int(cap.get(3)), int(cap.get(4))))
# /recording


# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        start_process_time = time.time()

        frame_counter += 1

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        # dynamically adjust the length of the sequence using the variable from above
        sequence = sequence[-length_of_sequence:]

        if len(sequence) == length_of_sequence:

            zero_frame = np.zeros_like(sequence[0])  # Creates a zero array with the same shape as a frame

            # overwrites zero_frame with the static
            zero_frame = static_frame

            padding = [zero_frame] * (int((30 - len(sequence))/2))

            # pad the actual sequence from left and right
            padded_sequence = padding + sequence + padding

            # Ensure that the padded sequence is exactly 30 frames long
            padded_sequence = padded_sequence[:30]

            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)], round(max(res),2))
            predictions.append(np.argmax(res))
            #  my_predictions = list(dict.fromke<ys(predictions)) --> another way how to get rid of duplicates and keep the order of the elements in the list


        #3. Viz logic
            # if np.unique(predictions[-2:])[0]==np.argmax(res): <-- wrong line of code since .unique sorts the elements in the list alphabetically!!!
            
            # if mode(predictions[-3:])[0]==np.argmax(res):


            is_silent_sign = actions[np.argmax(res)] == silent_sign_name

            if (np.unique(predictions[-no_of_reps_to_accept:])[0]==np.argmax(res) 
                and (np.unique(predictions[-no_of_reps_to_accept:]).shape[0]==1) # additional condition to check if the returned unique list has only one element
                and not is_silent_sign
                ): 


                if (res[np.argmax(res)] > threshold) and (actions[np.argmax(res)] != last_word):
                    all_words.append(actions[np.argmax(res)]) 
                    if len(sentence) >= num_of_words:
                        time.sleep(3) 
                        sentence = []
                        sentence.append(actions[np.argmax(res)])
                        last_word = actions[np.argmax(res)]
                        frame_counter = 0
                    elif len(sentence) > 0: 
                        sentence.append(actions[np.argmax(res)])
                        last_word = actions[np.argmax(res)]
                        frame_counter = 0
                    elif len(sentence) == 0:
                        sentence.append(actions[np.argmax(res)])
                        last_word = actions[np.argmax(res)]
                        frame_counter = 0
                    # the same thing:
                    # else:
                    #     sentence.append(actions[np.argmax(res)])
                        
                        
            # if len(sentence) > 5:
            #     sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, threshold)
       
        if frame_counter == 15:
            sentence = []
            # last_word = ""
            frame_counter = 0   

        # Get the width of the image
        image_width = image.shape[1]

        # Set the x coordinate for the text
        text_x = image_width - 200  # 200 is an estimate of the text width, adjust as needed

        # cv2.putText(image, f"frames: {frame_counter}", (text_x,50),
        #             cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)



        # cv2.putText(image, f"last word: {last_word}", (50,50),
        #             cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # cv2.putText(image, f"frames: {frame_counter}", (50,50),
        #             cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 1, cv2.LINE_AA)
        # cv2.putText(image, f"All detected words: {', '.join(all_words)}", (0,50),
        #             cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.rectangle(image, (0, 660), (1280, 720), (158, 128, 107), -1) # TODO : make it more transperant
        cv2.putText(image, ', '.join(sentence), (50,710),
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        
        # FPS fixin
        process_time = time.time() - start_process_time
        print(f"Processing time: {process_time:.2f}s")


        frame_count_for_fps += 1


        if frame_count_for_fps % 10 == 0:
            end_time = time.time()
            elapsed = end_time - start_time
            actual_fps = frame_count_for_fps / elapsed
            fps_list.append(actual_fps)
            print("Actual FPS:", actual_fps)
            # Reset timer and counter
            start_time = time.time()
            frame_count_for_fps = 0
            
        # Display the calculated FPS on the frame

        # frame_counter_text = f"{frame_counter}"
        # cv2.putText(image, frame_counter_text, (1170, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2, cv2.LINE_AA)

        fps_text = f"FPS {actual_fps:.2f}"     
        cv2.putText(image, fps_text, (1090, 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2, cv2.LINE_AA)
        

        fps_difference = ((actual_fps - fps_list[-2]) / fps_list[-2]) * 100 if len(fps_list) > 1 else 0
        
        if round(fps_difference) == 0: 
            fps_difference_text = f" 0.0%"
        elif fps_difference < 0: 
            fps_difference_text = f"{fps_difference:.1f}%"
        else: 
            fps_difference_text = f"+{fps_difference:.1f}%"

        cv2.putText(image, fps_difference_text, (1140, 90), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2, cv2.LINE_AA)




        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        # write the frame in the video recording
        out.write(image)

        # FIXIN FPS
        # Calculate the time to wait
        elapsed = time.time() - last_time
        wait_time = max(0, frame_time - elapsed)
        print(f"Elapsed time: {elapsed:.2f}s, Waiting for: {wait_time:.2f}s")
        time.sleep(wait_time)
        last_time = time.time()


        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('t'):
            break
    
    #release the recording
    out.release()

    cap.release()
    cv2.destroyAllWindows()
    cv2.waitKey(1)
# Out:
# Requested Resolution: 1280x720, Actual Resolution: 1280x720
# Requested FPS: 30, Actual FPS: 30.0
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.57s
# Elapsed time: 0.70s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.15s
# Elapsed time: 0.19s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.10s
# Elapsed time: 0.14s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.11s
# Elapsed time: 0.14s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.13s
# Elapsed time: 0.17s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.11s
# Elapsed time: 0.14s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.12s
# Elapsed time: 0.15s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.12s
# Elapsed time: 0.14s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.12s
# Elapsed time: 0.16s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.11s
# Actual FPS: 0.661559484263904
# Elapsed time: 0.14s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.10s
# Elapsed time: 0.13s, Waiting for: 0.02s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.12s
# Elapsed time: 0.15s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.08s
# Elapsed time: 0.12s, Waiting for: 0.03s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.10s
# Elapsed time: 0.13s, Waiting for: 0.01s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.08s
# Elapsed time: 0.11s, Waiting for: 0.03s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.11s
# Elapsed time: 0.13s, Waiting for: 0.01s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.11s
# Elapsed time: 0.14s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.10s
# Elapsed time: 0.13s, Waiting for: 0.01s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.13s
# Elapsed time: 0.16s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.10s
# Actual FPS: 6.6221015012166475
# Elapsed time: 0.13s, Waiting for: 0.01s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.14s
# Elapsed time: 0.17s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.09s
# Elapsed time: 0.12s, Waiting for: 0.02s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.12s
# Elapsed time: 0.15s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.10s
# Elapsed time: 0.13s, Waiting for: 0.01s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.11s
# Elapsed time: 0.13s, Waiting for: 0.01s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.10s
# Elapsed time: 0.13s, Waiting for: 0.01s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.09s
# Elapsed time: 0.12s, Waiting for: 0.02s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.12s
# Elapsed time: 0.15s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Processing time: 0.11s
# Elapsed time: 0.14s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Bread 0.95
# Processing time: 0.23s
# Actual FPS: 6.095635832358039
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Bread 0.95
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Bread 0.95
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Bread 0.93
# Processing time: 0.25s
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Bread 0.88
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Bread 0.77
# Processing time: 0.29s
# Elapsed time: 0.33s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Bread 0.49
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# No 0.59
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Yes 0.48
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Yes 0.74
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Yes 0.89
# Processing time: 0.23s
# Actual FPS: 3.691635091861274
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Yes 0.95
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Yes 0.95
# Processing time: 0.33s
# Elapsed time: 0.38s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Yes 0.82
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NoHands 0.56
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NoHands 0.22
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NoHands 0.19
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NoHands 0.62
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NoHands 0.99
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NoHands 0.98
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NoHands 0.95
# Processing time: 0.21s
# Actual FPS: 3.840151763810246
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NoHands 0.88
# Processing time: 0.28s
# Elapsed time: 0.32s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NoHands 0.67
# Processing time: 0.24s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NoHands 0.39
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Yes 0.22
# Processing time: 0.18s
# Elapsed time: 0.21s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Yes 0.26
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Hi 0.37
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Hi 0.49
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Hi 0.55
# Processing time: 0.22s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Hi 0.55
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Hi 0.49
# Processing time: 0.20s
# Actual FPS: 4.08071167746151
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Hi 0.36
# Processing time: 0.30s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NoHands 0.35
# Processing time: 0.20s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NoHands 0.5
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NoHands 0.63
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NoHands 0.71
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NoHands 0.74
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NoHands 0.71
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NoHands 0.58
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NoHands 0.38
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NoHands 0.21
# Processing time: 0.31s
# Actual FPS: 3.7314733189191824
# Elapsed time: 0.33s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Hi 0.23
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NoHands 0.21
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Hi 0.23
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Hi 0.31
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Hi 0.51
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# background 0.6
# Processing time: 0.33s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# background 0.58
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# background 0.33
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# You 0.44
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# You 0.56
# Processing time: 0.20s
# Actual FPS: 3.7486120237176817
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# You 0.58
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# You 0.56
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# You 0.48
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Yes 0.62
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Yes 0.76
# Processing time: 0.28s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Yes 0.85
# Processing time: 0.22s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Yes 0.88
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Yes 0.89
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Yes 0.9
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Yes 0.91
# Processing time: 0.24s
# Actual FPS: 3.902663789040674
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Yes 0.93
# Processing time: 0.33s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Yes 0.95
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Yes 0.92
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Yes 0.92
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Yes 0.92
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Yes 0.91
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Yes 0.91
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Yes 0.91
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Yes 0.83
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Yes 0.71
# Processing time: 0.29s
# Actual FPS: 3.8288830586486866
# Elapsed time: 0.33s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Yes 0.68
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Yes 0.54
# Processing time: 0.22s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Yes 0.52
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Yes 0.54
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Yes 0.49
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Hi 0.33
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Hi 0.35
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Tired 0.27
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Tired 0.31
# Processing time: 0.28s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Tired 0.35
# Processing time: 0.22s
# Actual FPS: 3.923913772584608
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Tired 0.34
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Me 0.29
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Me 0.32
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Me 0.34
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Me 0.31
# Processing time: 0.30s
# Elapsed time: 0.32s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Me 0.25
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Me 0.17
# Processing time: 0.24s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NoHands 0.23
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NoHands 0.27
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NoHands 0.25
# Processing time: 0.20s
# Actual FPS: 4.007426099447094
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NoHands 0.23
# Processing time: 0.25s
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# NoHands 0.27
# Processing time: 0.34s
# Elapsed time: 0.37s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NoHands 0.2
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Me 0.18
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Me 0.2
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Me 0.2
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Me 0.19
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Me 0.19
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Chocolate 0.61
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Chocolate 0.79
# Processing time: 0.30s
# Actual FPS: 3.6798044177438642
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Chocolate 0.94
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chocolate 0.98
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chocolate 0.98
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Chocolate 0.99
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Chocolate 0.99
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Chocolate 0.99
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Chocolate 0.99
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Chocolate 0.99
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Chocolate 0.99
# Processing time: 0.29s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Chocolate 0.99
# Processing time: 0.23s
# Actual FPS: 3.818918098975832
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Chocolate 0.99
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Chocolate 0.99
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Chocolate 0.99
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chocolate 0.99
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chocolate 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Chocolate 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Chocolate 0.99
# Processing time: 0.25s
# Elapsed time: 0.30s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Chocolate 0.99
# Processing time: 0.25s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chocolate 0.98
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Chocolate 0.97
# Processing time: 0.22s
# Actual FPS: 3.8374085079079743
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Chocolate 0.76
# Processing time: 0.27s
# Elapsed time: 0.30s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.71
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.94
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Happy 0.97
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Happy 0.98
# Processing time: 0.32s
# Elapsed time: 0.35s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.99
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.99
# Processing time: 0.23s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.99
# Processing time: 0.22s
# Actual FPS: 3.8086257941326354
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.98
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Happy 0.98
# Processing time: 0.31s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.98
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Happy 0.97
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.96
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.93
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.81
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Tired 0.34
# Processing time: 0.28s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Me 0.31
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Me 0.2
# Processing time: 0.20s
# Actual FPS: 3.7381499032064034
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NoHands 0.57
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NoHands 0.97
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NoHands 0.94
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NoHands 0.74
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# It 0.71
# Processing time: 0.30s
# Elapsed time: 0.33s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# It 0.95
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# It 0.99
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# It 0.99
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# It 1.0
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# It 1.0
# Processing time: 0.22s
# Actual FPS: 3.951987119377919
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# It 0.99
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# It 0.99
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# It 0.98
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# It 0.93
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# It 0.55
# Processing time: 0.22s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Bread 0.83
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Bread 0.94
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Bread 0.96
# Processing time: 0.20s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Bread 0.97
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Bread 0.96
# Processing time: 0.21s
# Actual FPS: 4.029481678475472
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Bread 0.93
# Processing time: 0.29s
# Elapsed time: 0.32s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Bread 0.84
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Bread 0.6
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# It 0.52
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# It 0.63
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# It 0.62
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# It 1.0
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# It 1.0
# Processing time: 0.33s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# It 0.99
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# It 0.98
# Processing time: 0.21s
# Actual FPS: 3.6951010247039333
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# It 0.91
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Bread 0.56
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Bread 0.93
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Bread 0.98
# Processing time: 0.30s
# Elapsed time: 0.33s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Bread 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Bread 0.99
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Bread 0.99
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Bread 0.99
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Bread 0.99
# Processing time: 0.30s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Bread 0.99
# Processing time: 0.23s
# Actual FPS: 3.582469141665367
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Bread 0.99
# Processing time: 0.22s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Bread 0.99
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Bread 0.99
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Bread 0.99
# Processing time: 0.22s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Bread 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Bread 0.99
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Bread 0.98
# Processing time: 0.31s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Bread 0.96
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Bread 0.89
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Hungry 0.44
# Processing time: 0.22s
# Actual FPS: 3.9317949574119226
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Tired 0.98
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Tired 0.98
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.96
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Happy 0.96
# Processing time: 0.28s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.97
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Happy 0.97
# Processing time: 0.25s
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.97
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Happy 0.96
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Happy 0.96
# Processing time: 0.31s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Happy 0.97
# Processing time: 0.23s
# Actual FPS: 3.6652414274390286
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Happy 0.97
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.88
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# It 0.48
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Feel 0.91
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Feel 0.85
# Processing time: 0.18s
# Elapsed time: 0.21s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# It 0.49
# Processing time: 0.26s
# Elapsed time: 0.30s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Happy 0.54
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Tired 0.52
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Happy 0.5
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Happy 0.9
# Processing time: 0.21s
# Actual FPS: 3.9007289016923883
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Tired 0.53
# Processing time: 0.20s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Tired 0.94
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Tired 0.97
# Processing time: 0.19s
# Elapsed time: 0.21s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Tired 0.96
# Processing time: 0.33s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tired 0.95
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Tired 0.98
# Processing time: 0.24s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Tired 0.98
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tired 0.98
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Tired 0.98
# Processing time: 0.27s
# Elapsed time: 0.30s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tired 0.98
# Processing time: 0.28s
# Actual FPS: 3.696215002954378
# Elapsed time: 0.32s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tired 0.98
# Processing time: 0.21s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Tired 0.98
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Tired 0.98
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Tired 0.98
# Processing time: 0.20s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Tired 0.98
# Processing time: 0.26s
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Tired 0.98
# Processing time: 0.26s
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Tired 0.98
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Tired 0.99
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Tired 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Tired 0.99
# Processing time: 0.21s
# Actual FPS: 3.8977966592337583
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Tired 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Tired 0.99
# Processing time: 0.30s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Tired 0.99
# Processing time: 0.28s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Tired 0.99
# Processing time: 0.27s
# Elapsed time: 0.30s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tired 0.99
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Chocolate 0.59
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Happy 0.51
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Happy 0.59
# Processing time: 0.35s
# Elapsed time: 0.39s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Happy 0.7
# Processing time: 0.21s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Happy 0.89
# Processing time: 0.19s
# Actual FPS: 3.574616370215462
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Happy 0.95
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Happy 0.96
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Happy 0.96
# Processing time: 0.22s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.95
# Processing time: 0.21s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Happy 0.93
# Processing time: 0.35s
# Elapsed time: 0.40s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Happy 0.86
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Happy 0.76
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Happy 0.72
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.73
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.56
# Processing time: 0.20s
# Actual FPS: 3.906478565753824
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Happy 0.41
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Tired 0.41
# Processing time: 0.32s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Tired 0.57
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Tired 0.69
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Tired 0.79
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Tired 0.84
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tired 0.85
# Processing time: 0.25s
# Elapsed time: 0.29s, Waiting for: 0.00s
# ...
# Happy 0.52
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Happy 0.77
# Processing time: 0.34s
# Elapsed time: 0.37s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Happy 0.96
# Processing time: 0.20s
# Actual FPS: 3.6515938913975936
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.99
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Happy 0.99
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.99
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Happy 0.99
# Processing time: 0.31s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Happy 0.99
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Happy 0.99
# Processing time: 0.22s
# Actual FPS: 3.858413302521006
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.98
# Processing time: 0.24s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Happy 0.96
# Processing time: 0.27s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Happy 0.92
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Happy 0.77
# Processing time: 0.24s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.47
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Chocolate 0.69
# Processing time: 0.31s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Chocolate 0.82
# Processing time: 0.26s
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Chocolate 0.7
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Tired 0.9
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tired 0.99
# Processing time: 0.23s
# Actual FPS: 3.5982869826518344
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Tired 0.99
# Processing time: 0.29s
# Elapsed time: 0.33s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Tired 0.99
# Processing time: 0.25s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Tired 0.98
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Chocolate 0.83
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Chocolate 0.94
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Tired 0.6
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Happy 0.51
# Processing time: 0.30s
# Elapsed time: 0.33s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Chocolate 0.5
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Chocolate 0.81
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chocolate 0.92
# Processing time: 0.20s
# Actual FPS: 3.700284232514866
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Chocolate 0.96
# Processing time: 0.22s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Chocolate 0.98
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Chocolate 0.98
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Chocolate 0.99
# Processing time: 0.35s
# Elapsed time: 0.39s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chocolate 0.89
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Happy 0.97
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Happy 0.99
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.99
# Processing time: 0.22s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Happy 0.98
# Processing time: 0.31s
# Actual FPS: 3.605228112999292
# Elapsed time: 0.35s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Tired 0.6
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Happy 0.99
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Happy 0.99
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Happy 0.99
# Processing time: 0.20s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Happy 0.99
# Processing time: 0.32s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Happy 0.99
# Processing time: 0.21s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Happy 0.99
# Processing time: 0.23s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Happy 0.99
# Processing time: 0.34s
# Elapsed time: 0.37s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Happy 0.99
# Processing time: 0.27s
# Elapsed time: 0.31s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Happy 0.99
# Processing time: 0.23s
# Actual FPS: 3.4800400482590317
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Happy 0.99
# Processing time: 0.36s
# Elapsed time: 0.40s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Happy 0.99
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Happy 0.99
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Happy 0.98
# Processing time: 0.31s
# Elapsed time: 0.34s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Happy 0.98
# Processing time: 0.27s
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.97
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Happy 0.94
# Processing time: 0.31s
# Elapsed time: 0.35s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Happy 0.74
# Processing time: 0.16s
# Elapsed time: 0.19s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Feel 0.3
# Processing time: 0.15s
# Elapsed time: 0.18s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Me 0.35
# Processing time: 0.25s
# Actual FPS: 3.575946960460771
# Elapsed time: 0.29s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NoHands 0.2
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NoHands 0.49
# Processing time: 0.16s
# Elapsed time: 0.20s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# NoHands 0.57
# Processing time: 0.38s
# Elapsed time: 0.46s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NoHands 0.44
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Me 0.19
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Me 0.34
# Processing time: 0.36s
# Elapsed time: 0.40s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Hi 0.26
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# NoHands 0.24
# Processing time: 0.19s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Hi 0.39
# Processing time: 0.21s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# background 0.49
# Processing time: 0.14s
# Actual FPS: 3.6114493071582796
# Elapsed time: 0.17s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# background 0.73
# Processing time: 0.21s
# Elapsed time: 0.25s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# background 0.85
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# background 0.86
# Processing time: 0.28s
# Elapsed time: 0.32s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# background 0.77
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# background 0.49
# Processing time: 0.18s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# You 0.65
# Processing time: 0.24s
# Elapsed time: 0.28s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# You 0.75
# Processing time: 0.24s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# You 0.69
# Processing time: 0.22s
# Elapsed time: 0.27s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# You 0.52
# Processing time: 0.32s
# Elapsed time: 0.35s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Yes 0.38
# Processing time: 0.20s
# Actual FPS: 3.6426241945815856
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Yes 0.45
# Processing time: 0.21s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Yes 0.44
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Yes 0.34
# Processing time: 0.20s
# Elapsed time: 0.24s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Hi 0.22
# Processing time: 0.36s
# Elapsed time: 0.37s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Hi 0.22
# Processing time: 0.20s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Hi 0.22
# Processing time: 0.19s
# Elapsed time: 0.23s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Hi 0.31
# Processing time: 0.20s
# Elapsed time: 0.22s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Hi 0.29
# Processing time: 0.23s
# Elapsed time: 0.26s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Hi 0.25
# Processing time: 0.32s
# Elapsed time: 0.36s, Waiting for: 0.00s
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Hi 0.21
# Processing time: 0.19s
# Actual FPS: 3.8085504022478442
# Elapsed time: 0.21s, Waiting for: 0.00s

# %%
fps_list
# Out:
# []

# %%
# print the detected words
print(f"All the words that have been detected are [{len(all_words)}] and they are: {', '.join(all_words)}")
print(f"The last words that have been detected and printed out are [{len(sentence)}] and they are: {', '.join(sentence)}")
# Out:
# All the words that have been detected are [0] and they are:
# The last words that have been detected and printed out are [0] and they are:
